# %% [markdown]
# # **1. Importação de Bibliotecas**

# %% [markdown]
# Bibliotecas padrão para manipulação de dados e visualização.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.16.4-py3-none-any.whl.metadata (23 kB)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.40-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.11/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.11/dist-packages (from bertopic) (5.24.1)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (1.6.0)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (3.3.1)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.11/dist-packages (from bertopic) (4.67.1)
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap_learn-0.5.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.13.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from hdbscan>=0.8.29->bertopic) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.5->bertopic) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=4.7.0->bertopic) (24.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.5.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.47.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.5.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.27.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=0.4.1->bertopic) (11.1.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2024.10.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (4.12.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.5.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2024.12.14)
# Downloading bertopic-0.16.4-py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 5.6 MB/s eta 0:00:00
# Downloading hdbscan-0.8.40-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 44.2 MB/s eta 0:00:00
# Downloading umap_learn-0.5.7-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 5.9 MB/s eta 0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: pynndescent, hdbscan, umap-learn, bertopic
# Successfully installed bertopic-0.16.4 hdbscan-0.8.40 pynndescent-0.5.13 umap-learn-0.5.7

# %% [markdown]
# Ferramentas utilizadas para modelagem de tópicos e redução de dimensionalidade.

# %%
from bertopic import BERTopic
from umap import UMAP
from sklearn.feature_extraction.text import CountVectorizer
from hdbscan import HDBSCAN
from bertopic.vectorizers import ClassTfidfTransformer
from sentence_transformers import SentenceTransformer

# %% [markdown]
# Biblioteca para manipulação de linguagem natural, usada aqui para lidar com *stopwords* no português.

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords_pt = set(stopwords.words('portuguese'))
stopwords_pt=list(stopwords_pt)
vectorizer_model  = CountVectorizer(stop_words=stopwords_pt)

# %% [markdown]
# Usado para "montar" o Google Drive no Google Colab, possibilitando acesso a arquivos armazenados nele.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **2. Pré-Processamento**

# %%
df=pd.read_csv('/content/drive/MyDrive/Geral.csv', sep='|')
df.head()
# Out:
#                                                 text
# 0  Marta tem 6 bolas de ouro, mas ele queria ter ...
# 1                               Mancada fulminante 😅
# 2  Sem viés ideológico assisti todos os jogos na ...
# 3                         Querem so lacrar mais nada
# 4  Eu nem sabia que tava tendo copa do mundo femi...

# %% [markdown]
# Substituir as marcações [mention] encontradas no texto por uma string vazia (''), removendo-as.

# %%
def remover_tag(texto):
    return texto.replace('[mention]', '')

# %% [markdown]
# Decodificar entidades HTML para caracteres normais.

# %%
import html
def decode_html_entities(text):
    decoded_text = html.unescape(text)
    return decoded_text

# %% [markdown]
# Remover URLs do texto utilizando uma expressão regular.

# %%
def remove_links(text):
    link_pattern = r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))href+="about:invalid#zCSafez'
    text_without_links = re.sub(link_pattern, '', text)

    return text_without_links

# %% [markdown]
# Remover palavras ou padrões que representam risadas.

# %%
def remove_risada(text):
    padrao_risada = r'\b(?:k{2, }|haha|hehe|hahaha|hehehe|rsrs)\b'
    texto_sem_risada = re.sub(padrao_risada, '', text, flags=re.IGNORECASE)
    return texto_sem_risada

# %% [markdown]
# Substituir todos os emojis encontrados no texto por uma string vazia (''), removendo-os.

# %%
import re

def caracter_especial_emoji(text):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # Emojis gerais
                               u"\U0001F300-\U0001F5FF"  # Emojis de símbolos e transportes
                               u"\U0001F700-\U0001F77F"  # Emojis de alquimia
                               u"\U0001F780-\U0001F7FF"  # Emojis de Geometria
                               u"\U0001F800-\U0001F8FF"  # Emojis de sinais gregos
                               u"\U0001F900-\U0001F9FF"  # Emojis de sinais suplementares
                               u"\U0001FA00-\U0001FA6F"  # Emojis de esportes
                               u"\U0001FA70-\U0001FAFF"  # Emojis de comida
                               u"\U0001F680-\U0001F6FF"  # Emojis de transporte terrestre
                               "]+", flags=re.UNICODE)
    text = emoji_pattern.sub(r'', text)
    return text

# %%
df['text'] = df['text'].apply(caracter_especial_emoji)

# %% [markdown]
# Remover quebras de linha (\n) do texto.

# %%
def remove_newlines(text):
    texto_limpo = text.replace("\n", " ")
    return texto_limpo

# %%
df['text'] = df['text'].apply(remove_newlines)

# %%
df
# Out:
#                                                     text
# 0      Marta tem 6 bolas de ouro, mas ele queria ter ...
# 1                                    Mancada fulminante
# 2      Sem viés ideológico assisti todos os jogos na ...
# 3                             Querem so lacrar mais nada
# 4      Eu nem sabia que tava tendo copa do mundo femi...
# ...                                                  ...
# 11918  Começou errado ja no critério de convocação da...
# 11919  @Raphael Abreu kkkkkkkkkkk se nao empurrar dir...
# 11920                         A bola nao entrou so isso.
# 11921                       Empataram com um time sub 15
# 11922                        Eu também gostaria de saber
#
# [11923 rows x 1 columns]

# %% [markdown]
# Transformar a coluna "text" em uma lista de strings para a análise de tópicos e configuração para rotular os textos.

# %%
documents = df['text'].tolist()

# %%
custom_headers = ['Document']

# %%
df['text']
# Out:
# 0        Marta tem 6 bolas de ouro, mas ele queria ter ...
# 1                                      Mancada fulminante
# 2        Sem viés ideológico assisti todos os jogos na ...
# 3                               Querem so lacrar mais nada
# 4        Eu nem sabia que tava tendo copa do mundo femi...
#                                ...
# 11918    Começou errado ja no critério de convocação da...
# 11919    @Raphael Abreu kkkkkkkkkkk se nao empurrar dir...
# 11920                           A bola nao entrou so isso.
# 11921                         Empataram com um time sub 15
# 11922                          Eu também gostaria de saber
# Name: text, Length: 11923, dtype: object

# %% [markdown]
# # **3. Bertopic**

# %%
from bertopic.representation import MaximalMarginalRelevance
from transformers import pipeline
from bertopic.representation import TextGeneration
from bertopic.representation import KeyBERTInspired
from umap import UMAP
from sklearn.feature_extraction.text import CountVectorizer
from hdbscan import HDBSCAN
from bertopic.vectorizers import ClassTfidfTransformer
from sentence_transformers import SentenceTransformer
from bertopic import BERTopic

# %%
umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine')
hdbscan_model = HDBSCAN(min_cluster_size=15, metric='euclidean', cluster_selection_method='eom', prediction_data=True)
topic_model = BERTopic(umap_model=umap_model, embedding_model = 'paraphrase-multilingual-mpnet-base-v2', language='multilingual', vectorizer_model  = vectorizer_model  )

# %% [markdown]
# Devido à natureza estocástica do UMAP, os resultados do BERTopic podem ser diferentes mesmo que você execute o mesmo código várias vezes. Se quiser reproduzir os resultados, às custas do desempenho, você pode definir um random_state no UMAP para evitar qualquer comportamento estocástico:

# %%
from bertopic import BERTopic
from umap import UMAP

umap_model = UMAP(n_neighbors=15, n_components=5,
                  min_dist=0.0, metric='cosine', random_state=42)
topic_model = BERTopic(umap_model=umap_model)

# %%
topics, probs = topic_model.fit_transform(documents)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                   Name  \
# 0       -1   3254                     -1_que_de_no_seleo
# 1        0    942  0_feminino_futebol_masculino_assistir
# 2        1    845       1_lacrao_lacradoras_lacra_lacrar
# 3        2    362                2_kkkk_kkkkk_kkk_kkkkkk
# 4        3    360      3_brasil_brasileira_do_brasileiro
# ..     ...    ...                                    ...
# 125    124     11      124_feminista_bl_feministas_cheia
# 126    125     11             125_rapinoe_2019_fala_isso
# 127    126     10      126_vergonha_voce_feioas_verhonha
# 128    127     10   127_13_adorei_adoreichupaaa_londinho
# 129    128     10        128_cara_falar_deixa_impossivel
#
#                                         Representation  \
# 0      [que, de, no, seleo, com, pra, da, tem, um, do]
# 1    [feminino, futebol, masculino, assistir, no, d...
# 2    [lacrao, lacradoras, lacra, lacrar, muita, lac...
# 3    [kkkk, kkkkk, kkk, kkkkkk, kkkkkkk, kkkkkkkk, ...
# 4    [brasil, brasileira, do, brasileiro, no, que, ...
# ..                                                 ...
# 125  [feminista, bl, feministas, cheia, lacrao, pou...
# 126  [rapinoe, 2019, fala, isso, em, tore, branca, ...
# 127  [vergonha, voce, feioas, verhonha, adversaria,...
# 128  [13, adorei, adoreichupaaa, londinho, lu, lula...
# 129  [cara, falar, deixa, impossivel, vapeta, preul...
#
#                                    Representative_Docs
# 0    [Agora que a marta vai se aposentar agora esqu...
# 1    [Futebol feminino não dá pra assistir..., Fute...
# 2    [Quem lacra não lucra, Quem lacra não lucra !,...
# 3    [ISSO AÍ KKKKK, Que delícia kkkkk, Kkkkkkk sel...
# 4    [@marcos sousa difícil é mais fácil o Brasil g...
# ..                                                 ...
# 125  [Muita LACRAÇÃO e COITADISMO FEMINISTA, e pouc...
# 126  [Fala isso pra Rapinoe em 2019., Fala isso pra...
# 127  [Verdade a mídia de merda Neymar um lixo seleç...
# 128                      [Adorei kk, Lula 13, Lula 13]
# 129  [Ela não deixa o cara falar., Esse cara é duas...
#
# [130 rows x 5 columns]

# %% [markdown]
# # **4. Hierarquização**

# %% [markdown]
# Cálculo da matriz de similaridade entre os tópicos, e organização das informações em um formato tabular, identificando os 20 pares de tópicos mais similares.

# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

distance_matrix = cosine_similarity(np.array(topic_model.topic_embeddings_))
dist_df = pd.DataFrame(distance_matrix, columns=topic_model.topic_labels_.values(),
                       index=topic_model.topic_labels_.values())

tmp = []
for rec in dist_df.reset_index().to_dict('records'):
    t1 = rec['index']
    for t2 in rec:
        if t2 == 'index':
            continue
        tmp.append(
            {
                'topic1': t1,
                'topic2': t2,
                'distance': rec[t2]
            }
        )

pair_dist_df = pd.DataFrame(tmp)

pair_dist_df = pair_dist_df[(pair_dist_df.topic1.map(lambda x: not x.startswith('-1'))) &
                            (pair_dist_df.topic2.map(lambda x: not x.startswith('-1')))]
pair_dist_df = pair_dist_df[pair_dist_df.topic1 < pair_dist_df.topic2]
pair_dist_df.sort_values('distance', ascending=False).head(20)
# Out:
#                                                   topic1  \
# 15436              117_concordo_literalmente_pilhado_com
# 4689                 35_masculina_feminina_seleo_imagina
# 7029                   53_feminina_pilhado_seleo_orgasmo
# 15781                   120_copa_feminina_europa_lagrima
# 2605                    19_brasileiro_futebol_brasil_pas
# 15395              117_concordo_literalmente_pilhado_com
# 13425                         102_copa_ganha_copas_1914e
# 1439                 10_brasileira_feminina_brasil_seleo
# 15652  119_kkkkkkkkkk_kkkkkkkkkkkkkk_kkkkkkkkkkkk_kkk...
# 4040                       30_deixa_falar_ningum_ninguem
# 1005                    6_jamaica_frana_vaquinha_empatou
# 16559                  126_vergonha_voce_feioas_verhonha
# 4746                 35_masculina_feminina_seleo_imagina
# 3149                 23_lacrao_feminino_futebol_feminina
# 154                0_feminino_futebol_masculino_assistir
# 1496                 10_brasileira_feminina_brasil_seleo
# 2604                    19_brasileiro_futebol_brasil_pas
# 8589             65_femininas_jogadoras_moleques_aqueles
# 2217               16_jamaica_feminina_vaquinha_feminino
# 1551                 10_brasileira_feminina_brasil_seleo
#
#                                           topic2  distance
# 15436  95_plenamente_concordo_totalmente_pilhado  0.945628
# 4689               8_feminina_seleo_essa_selecao  0.939813
# 7029               8_feminina_seleo_essa_selecao  0.932327
# 15781               50_copa_mundo_feminina_tendo  0.930657
# 2605                  4_futebol_pouco_muita_nada  0.929139
# 15395                54_concordo_100_com_pilhado  0.927613
# 13425                 34_copa_mundo_amrica_copas  0.926021
# 1439               8_feminina_seleo_essa_selecao  0.922485
# 15652     51_kkkkkkkkk_kkkkkkkkkkk_kkkkk_kkkkkkk  0.920070
# 4040                   9_pilhado_esse_foda_chato  0.917776
# 1005       94_guerreiras_jamaicanas_plin_jamaica  0.916465
# 16559          48_vergonha_gol_chutar_vergonhosa  0.912903
# 4746     65_femininas_jogadoras_moleques_aqueles  0.912747
# 3149           28_feminina_lacrao_seleo_lacracao  0.911833
# 154          23_lacrao_feminino_futebol_feminina  0.911359
# 1496     65_femininas_jogadoras_moleques_aqueles  0.910393
# 2604           3_brasil_brasileira_do_brasileiro  0.908866
# 8589               8_feminina_seleo_essa_selecao  0.906026
# 2217            6_jamaica_frana_vaquinha_empatou  0.905721
# 1551            120_copa_feminina_europa_lagrima  0.903257

# %% [markdown]
# Mesclagem

# %%
topic_model.merge_topics(df['text'], [[117, 95, 54], [35, 8, 53, 10, 65], [120, 50, 10], [19, 4], [102, 34], [119, 51], [30, 9], [6, 94, 16], [126, 48], ])
df['merged_topic'] = topic_model.topics_

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                               Name  \
# 0       -1   3254                                 -1_que_de_no_seleo
# 1        0    942                    0_feminino_futebol_masculino_no
# 2        1    845                   1_lacrao_lacradoras_lacra_lacrar
# 3        2    401                       2_jamaica_frana_vaquinha_pra
# 4        3    377                    3_futebol_brasileiro_pouco_nada
# ..     ...    ...                                                ...
# 111    110     11                         110_rapinoe_2019_fala_isso
# 112    111     11                  111_feminista_bl_feministas_cheia
# 113    112     11  112_hrefaboutinvalidzcsafezaa_hrefaboutinvalid...
# 114    113     10               113_13_adorei_adoreichupaaa_londinho
# 115    114     10                    114_cara_falar_deixa_impossivel
#
#                                         Representation  \
# 0      [que, de, no, seleo, com, pra, da, tem, um, do]
# 1    [feminino, futebol, masculino, no, assistir, d...
# 2    [lacrao, lacradoras, lacra, lacrar, muita, lac...
# 3    [jamaica, frana, vaquinha, pra, da, brasil, pa...
# 4    [futebol, brasileiro, pouco, nada, no, muita, ...
# ..                                                 ...
# 111  [rapinoe, 2019, fala, isso, em, pra, tore, bra...
# 112  [feminista, bl, feministas, cheia, lacrao, pou...
# 113  [hrefaboutinvalidzcsafezaa, hrefaboutinvalidzc...
# 114  [13, adorei, adoreichupaaa, londinho, lu, lula...
# 115  [cara, falar, deixa, impossivel, vapeta, preul...
#
#                                    Representative_Docs
# 0    [Agora que a marta vai se aposentar agora esqu...
# 1    [Futebol feminino não dá pra assistir..., Fute...
# 2    [Quem lacra não lucra , Quem lacra não lucra ,...
# 3    [Jamaica fez vaquinha pra ir pra copa do mundo...
# 4    [Futebol nada, Brasil não é mais o país do fut...
# ..                                                 ...
# 111  [Fala isso pra Rapinoe em 2019., Fala isso pra...
# 112  [Muita LACRAÇÃO e COITADISMO FEMINISTA, e pouc...
# 113  [A Pia é uma grande furada, o barco naufragou!...
# 114                      [Adorei kk, Lula 13, Lula 13]
# 115  [Ela não deixa o cara falar., Esse cara é duas...
#
# [116 rows x 5 columns]

# %%
custom_headers = ['Document']

# %% [markdown]
# Hierarquia

# %%
hierarchical_topics = topic_model.hierarchical_topics(df['text'])
# Out:
# 100%|██████████| 114/114 [00:00<00:00, 228.86it/s]

# %%
topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1ca51c02-a10d-44d7-8d7d-044a57b394e7" class="plotly-graph-div" style="height:1925px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ca51c02-a10d-44d7-8d7d-044a57b394e7")) {                    Plotly.newPlot(                        "1ca51c02-a10d-44d7-8d7d-044a57b394e7",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["tornando_busca_verdadeiro_agenda_inegvel","","","jogadoras_das_voes_metros_mudar"],"x":[0.0,0.8212272240086299,0.8212272240086299,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["feministas_querem_questo_igualdade_militantes","","","tornando_busca_verdadeiro_jogadoras_agenda"],"x":[0.0,0.8845923952347384,0.8845923952347384,0.8212272240086299],"xaxis":"x","y":[-5.0,-5.0,-20.0,-20.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["igualdade_feministas_representatividade_querem_emocionante","","","gay_lgbt_gays_homosexualidade_jovebs"],"x":[0.8845923952347384,0.9114648245461748,0.9114648245461748,0.0],"xaxis":"x","y":[-12.5,-12.5,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["cobrar_cobrana_cobrado_celebrar_cobra","","","investimento_altos_carro_falta_boas"],"x":[0.0,0.822402815441062,0.822402815441062,0.0],"xaxis":"x","y":[-45.0,-45.0,-55.0,-55.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["clubes_jogadores_serie_jogador_ganham","","","cbf_brasileiro_infelizmente_empresrios_est"],"x":[0.0,0.8846622944621897,0.8846622944621897,0.0],"xaxis":"x","y":[-65.0,-65.0,-75.0,-75.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["investimento_cobrar_cobrana_cobrado_elas","","","cbf_clubes_jogadores_brasileiro_serie"],"x":[0.822402815441062,0.9565532744321633,0.9565532744321633,0.8846622944621897],"xaxis":"x","y":[-50.0,-50.0,-70.0,-70.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["igualdade_feministas_representatividade_querem_emocionante","","","cbf_investimento_clubes_jogadores_cobrar"],"x":[0.9114648245461748,0.9706999783221444,0.9706999783221444,0.9565532744321633],"xaxis":"x","y":[-23.75,-23.75,-60.0,-60.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["criticar_criticou_crticas_feminina_medo","","","criticar_crtica_crticas_critica_tem"],"x":[0.0,0.4778379381175123,0.4778379381175123,0.0],"xaxis":"x","y":[-85.0,-85.0,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["meninas_essas_as_das_jogam","","","debate_poltica_ele_politicagem_povo"],"x":[0.0,0.8000034114026349,0.8000034114026349,0.0],"xaxis":"x","y":[-105.0,-105.0,-115.0,-115.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["criticar_crtica_crticas_criticou_critica","","","meninas_essas_as_debate_das"],"x":[0.4778379381175123,0.9066712827363181,0.9066712827363181,0.8000034114026349],"xaxis":"x","y":[-90.0,-90.0,-110.0,-110.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","text":["igualdade_feministas_querem_representatividade_questo","","","criticar_meninas_crtica_crticas_as"],"x":[0.9706999783221444,1.027139776354093,1.027139776354093,0.9066712827363181],"xaxis":"x","y":[-41.875,-41.875,-100.0,-100.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marke ...

# %% [markdown]
# Redução

# %%
topic_model.merge_topics(df['text'], [[56, 43, 52], [92, 62, 65, 47], [39, 13, 18, 46], [21, 1, 26], [24, 6, 9, 5, 10, 0, 3, 22], [27, 17], [100, 40, 83], [68, 91, 29, 57], [104, 70, 28, 51], [86, 20, 19, 33], [30, 35, 11, 16, 12, 67, 58, 73], [99, 98], [89, 55, 93, 80], [53, 111], [63, 23, 97], [36, 50], [110, 101, 96, 113, 105, 103, 31, 25, 99, 95, 109, 74], [15, 84, 77, 32, 38], [85, 14, 69, 102, 8, 114], [106, 37, 41, 61, 49], [48, 60, 54, 87, 82, 59, 44], [42, 79, 2, 45, 71], [81, 7, 72, 66, 4, 34, 75, 64, 112, 94], [78, 108, 107, 88]])
df['merged_topic'] = topic_model.topics_

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1   3254                                 -1_que_de_no_seleo
# 1       0   2607                          0_futebol_feminino_no_que
# 2       1    994                   1_lacrao_lacradoras_lacrar_lacra
# 3       2    812  2_kkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk_hrefa...
# 4       3    655                          3_neto_neymar_marta_panam
# 5       4    521                                4_jamaica_da_pra_no
# 6       5    450                      5_vampeta_pilhado_deixa_falar
# 7       6    316                          6_meninas_criticar_as_que
# 8       7    272                 7_prado_flvio_retrgrados_desprezam
# 9       8    269                  8_pilhado_certo_esporte_gritinhos
# 10      9    236                   9_treinadora_pia_cristiane_elias
# 11     10    198                   10_falou_parabns_pilhado_verdade
# 12     11    186                      11_seleo_masculina_essa_bosta
# 13     12    160            12_programa_bolsonarista_esse_bolsonaro
# 14     13    135                 13_concordo_plenamente_com_pilhado
# 15     14    135                         14_time_do_corinthians_sub
# 16     15    115                         15_globo_lixo_tv_globolixo
# 17     16    108                      16_cbf_investimento_clubes_de
# 18     17    101                           17_mais_uma_igualdade_do
# 19     18     85                            18_pau_ruins_nunca_como
# 20     19     80                           19_vergonha_uma_gol_essa
# 21     20     75                 20_igual_iguais_igualdade_direitos
# 22     21     63                            21_feito_faz_bem_vexame
# 23     22     43             22_feminista_feminismo_feministas_essa
# 24     23     22                   23_gay_lgbt_gays_homosexualidade
# 25     24     16                            24_boa_bora_neto_nippon
# 26     25     15              25_machismo_culpa_machista_estrutural
#
#                                        Representation  \
# 0     [que, de, no, seleo, da, com, do, pra, tem, um]
# 1   [futebol, feminino, no, que, de, brasil, seleo...
# 2   [lacrao, lacradoras, lacrar, lacra, muita, fut...
# 3   [kkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk, hrefa...
# 4   [neto, neymar, marta, panam, no, foi, do, ganh...
# 5   [jamaica, da, pra, no, que, seleo, para, de, b...
# 6   [vampeta, pilhado, deixa, falar, esse, cara, f...
# 7   [meninas, criticar, as, que, no, tem, pilhado,...
# 8   [prado, flvio, retrgrados, desprezam, buscando...
# 9   [pilhado, certo, esporte, gritinhos, trombadas...
# 10  [treinadora, pia, cristiane, elias, no, essa, ...
# 11  [falou, parabns, pilhado, verdade, tudo, verda...
# 12  [seleo, masculina, essa, bosta, que, fraca, de...
# 13  [programa, bolsonarista, esse, bolsonaro, pilh...
# 14  [concordo, plenamente, com, pilhado, 100, neto...
# 15  [time, do, corinthians, sub, 15, da, bueno, ga...
# 16  [globo, lixo, tv, globolixo, rede, oba, da, qu...
# 17  [cbf, investimento, clubes, de, que, um, tem, ...
# 18  [mais, uma, igualdade, do, querem, as, feminis...
# 19  [pau, ruins, nunca, como, ganharam, nada, ganh...
# 20  [vergonha, uma, gol, essa, seleo, foi, vergonh...
# 21  [igual, iguais, igualdade, direitos, querem, h...
# 22  [feito, faz, bem, vexame, concentrao, ruim, te...
# 23  [feminista, feminismo, feministas, essa, seleo...
# 24  [gay, lgbt, gays, homosexualidade, do, problem...
# 25  [boa, bora, neto, nippon, demerda, bolsanarist...
# 26  [machismo, culpa, machista, estrutural, patria...
#
#                                   Representative_Docs
# 0   [Agora que a marta vai se aposentar agora esqu...
# 1   [foi FEIO e tbm humilhante a desclassificação?...
# 2   [MUITA LACRAÇÃO E POUCO FUTEBOL, É MUITA LACRA...
# 3   [Kkkk, kkkk, Kkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk...
# 4   [Neto está há 0 dias sem falar do Neymar , Net...
# 5   [Parabéns Jamaica , Parabéns JAMAICA, Jamaica ...
# 6   [Pilhado não deixa ninguém falar, Deixa o Vamp...
# 7   [Essas meninas nunca jogaram nada o Neto está ...
# 8   [É uma vergonha o comportamento MACHISTA de jo...
# 9   [  TROMBADAS, GRITINHOS e CHITES AO AR !! Essa...
# 10  [CRISTIANE náo foi nem em 2019, essa PIA é uma...
# 11  [Falou tudo Pilhado, O Pilhado falou a verdade...
# 12  [A seleção masculina um bagaço também, E na ma...
# 13  [Vergonha e vc e esse seu programa q é uma por...
# 14  [Concordo com o pilhado, Concordo com pilhado....
# 15  [Esse Neto, o Galvão Bueno e o Datena são três...
# 16    [Seleção da globo lixo, Globo lixo, Globo lixo]
# 17  [Só esse idiota do pilhado para comparar um es...
# 18  [*Olha, vamos ser sinceros aqui: o futebol fem...
# 19  [Jogaram como sempre, perderam como nunca., Jo...
# 20     [Uma vergonha!!!, Uma vergonha, Uma vergonha ]
# 21  [DIREITOS IGUAIS, A SELEÇÃO MASCULINA É HORRÍV...
# 22                [Bem feito , bem feito , BEM FEITO]
# 23  [o problema das jogadoras do Brasil foi o femi...
# 24  [Fala merda não, retardado! Falar que a seleçã...
# 25                                  [Boa , Boa,  boa]
# 26  [A culpa é do patriarcado , dos homens , do ma...

# %%
topic_model.merge_topics(df['text'], [[-1, 2], [5, 8, 10, 13, 24], [6, 18, 19, 21], [17, 20], [22, 25]])
df['merged_topic'] = topic_model.topics_

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                        Name  \
# 0      -1   4066                          -1_que_de_no_seleo
# 1       0   2607                   0_futebol_no_feminino_que
# 2       1   1068            1_pilhado_vampeta_concordo_deixa
# 3       2    994              2_lacrao_de_lacradoras_futebol
# 4       3    655                      3_neto_neymar_marta_no
# 5       4    544                   4_meninas_criticar_que_no
# 6       5    521                         5_jamaica_da_no_que
# 7       6    272          6_prado_flvio_retrgrados_desprezam
# 8       7    236               7_treinadora_pia_cristiane_no
# 9       8    186                  8_seleo_masculina_essa_que
# 10      9    176                     9_igualdade_uma_mais_do
# 11     10    160       10_programa_esse_bolsonarista_pilhado
# 12     11    135                   11_time_do_corinthians_da
# 13     12    115                  12_globo_lixo_tv_globolixo
# 14     13    108               13_cbf_investimento_de_clubes
# 15     14     58  14_feminista_feminismo_machismo_feministas
# 16     15     22            15_gay_lgbt_gays_homosexualidade
#
#                                        Representation  \
# 0     [que, de, no, seleo, da, com, do, pra, tem, um]
# 1   [futebol, no, feminino, que, de, brasil, seleo...
# 2   [pilhado, vampeta, concordo, deixa, falar, fal...
# 3   [lacrao, de, lacradoras, futebol, seleo, lacra...
# 4   [neto, neymar, marta, no, panam, do, foi, de, ...
# 5   [meninas, criticar, que, no, de, tem, vergonha...
# 6   [jamaica, da, no, que, pra, seleo, de, para, d...
# 7   [prado, flvio, retrgrados, desprezam, buscando...
# 8   [treinadora, pia, cristiane, no, elias, essa, ...
# 9   [seleo, masculina, essa, que, bosta, de, fraca...
# 10  [igualdade, uma, mais, do, que, querem, no, as...
# 11  [programa, esse, bolsonarista, pilhado, bolson...
# 12  [time, do, corinthians, da, sub, 15, so, bueno...
# 13  [globo, lixo, tv, globolixo, rede, oba, da, qu...
# 14  [cbf, investimento, de, clubes, que, um, no, t...
# 15  [feminista, feminismo, machismo, feministas, c...
# 16  [gay, lgbt, gays, homosexualidade, do, de, fut...
#
#                                   Representative_Docs
# 0   [Essa seleção feminina, aquela seleção do Neym...
# 1   [Vampeta tentando justificar o injustificável,...
# 2   [Parabéns pilhado., E o Pilhado também, Pilhad...
# 3   [Muita lacração e pouco futebol!, Muita lacraç...
# 4   [Neto está há 0 dias sem falar do Neymar , Net...
# 5   [Temos que torcer para as meninas da seleção ....
# 6   [Parabéns Jamaica , Jamaica ✳️✳️✳️, Jamaica!!!...
# 7   [É uma vergonha o comportamento MACHISTA de jo...
# 8   [PÍFIA A PIA RIDÍCULO, *Pia, CRISTIANE náo foi...
# 9   [A seleção masculina um bagaço também, Seleção...
# 10  [*Olha, vamos ser sinceros aqui: o futebol fem...
# 11  [Vergonha e vc e esse seu programa q é uma por...
# 12  [Esse Neto, o Galvão Bueno e o Datena são três...
# 13    [Seleção da globo lixo, Globo lixo, Globo lixo]
# 14  [Só esse idiota do pilhado para comparar um es...
# 15  [o problema das jogadoras do Brasil foi o femi...
# 16  [Seleção Brasileira feminina só vai ganha Copa...

# %% [markdown]
# Extrair todos os documentos de cada tópico (arquivo csv)

# %%
doc_info = topic_model.get_document_info(documents)

from collections import defaultdict

topic_docs = defaultdict(list)
for index, row in doc_info.iterrows():
    topic = row['Topic']
    doc = row['Document']
    topic_docs[topic].append(doc)

target_topic = 0
documents_in_topic_0 = topic_docs[target_topic]
print(documents_in_topic_0)

topic_0_df = pd.DataFrame(documents_in_topic_0, columns=["Document"])

topic_0_file_name = "documents_in_topic_0.csv"

topic_0_df.to_csv(topic_0_file_name, index=False)

print(f"Documents in topic 0 saved to {topic_0_file_name}")
# Out:
# ['Sem viés ideológico assisti todos os jogos na TV caze não na rede esgoto que final parabéns Espanha e Inglaterra que espetáculo. Quanto ao fiasco do Brasil normal seja masculino e feminino', 'Eu nem sabia que tava tendo copa do mundo feminino ', 'O problema do Brasil foi a Bola', 'Brasil não e mais pais do futebol, Brasil masculino fudido, brasil sub 20 fudido, brasil feminino fudido tmb, ta tudo uma merda kkkkkkkkkkk
# Documents in topic 0 saved to documents_in_topic_0.csv

# %%
doc_info = topic_model.get_document_info(documents)

from collections import defaultdict

topic_docs = defaultdict(list)
for index, row in doc_info.iterrows():
    topic = row['Topic']
    doc = row['Document']
    topic_docs[topic].append(doc)

target_topic = 4
documents_in_topic_4 = topic_docs[target_topic]

topic_4_df = pd.DataFrame(documents_in_topic_4, columns=["Document"])

topic_4_file_name = "documents_in_topic_4.csv"

topic_4_df.to_csv(topic_4_file_name, index=False)

print(f"Documents in topic 4 saved to {topic_4_file_name}")
# Out:
# Documents in topic 4 saved to documents_in_topic_4.csv

# %% [markdown]
# Extrair os documentos *Outliers*

# %%
outliers = doc_info[doc_info['Topic'] == -1]

outlier_file_name = "outlier_documents.csv"
outliers.to_csv(outlier_file_name, index=False)

print(f"Outlier documents saved to {outlier_file_name}")
# Out:
# Outlier documents saved to outlier_documents.csv

# %% [markdown]
# # **Visualizações**

# %% [markdown]
# Gráfico de barras que exibe os tópicos mais relevantes e suas palavras-chave.

# %%
topic_model.visualize_barchart(top_n_topics = 15, n_words = 20)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5101d181-6990-44dd-8f64-021e9919c6c5" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5101d181-6990-44dd-8f64-021e9919c6c5")) {                    Plotly.newPlot(                        "5101d181-6990-44dd-8f64-021e9919c6c5",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.01937281756260355,0.023902051163053592,0.025614099810465165,0.02581134159086822,0.025934083785237753,0.033171243489207504,0.03403230295747612,0.03467708599980602,0.03570344471940614,0.042038298059601235],"y":["uma  ","feminina  ","do  ","seleo  ","brasil  ","de  ","que  ","feminino  ","no  ","futebol  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.032850563886517345,0.0338326829293927,0.03463889851330368,0.03508321135122182,0.039492042059807116,0.04848855491993091,0.04966927813810427,0.05809702939997422,0.07601095311428868,0.15570321582108468],"y":["certo  ","de  ","parabns  ","com  ","falou  ","falar  ","deixa  ","concordo  ","vampeta  ","pilhado  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.02969626042527592,0.030453943301504235,0.03090443365095108,0.031809879695006614,0.03227707006752455,0.03261229817577225,0.03296987430657789,0.03377912679104329,0.03475941178713787,0.08954479657300449],"y":["no  ","muita  ","que  ","lacra  ","lacrar  ","seleo  ","futebol  ","lacradoras  ","de  ","lacrao  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.02605499075855498,0.028607479821259153,0.028951182656457023,0.029391072912359262,0.03029683661428841,0.03117168288427971,0.034772027026896885,0.056702555998437126,0.0714928779709924,0.09443732259054309],"y":["ganhou  ","que  ","de  ","foi  ","do  ","panam  ","no  ","marta  ","neymar  ","neto  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.025049817294384182,0.025131589189328722,0.0283163285081697,0.028773317944469967,0.02908255702831003,0.029382180360107285,0.0314259913605198,0.03496535257119022,0.04285082431037662,0.046274480024568146],"y":["pilhado  ","nada  ","as  ","vergonha  ","tem  ","de  ","no  ","que  ","criticar  ","meninas  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.024339715497834483,0.02496426285524158,0.02543507316070241,0.02763099103711347,0.028328366447127853,0.032855498243182624,0.03417227013172326,0.03445529316374555,0.03585718602851179,0.12624104467311342],"y":["brasil  ","do  ","para  ","de  ","seleo  ","pra  ","que  ","no  ","da  ","jamaica  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0